# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutvij1998/E-Mail-extractor/blob/master/Address_identifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from requests import get
from bs4 import BeautifulSoup
import csv
import re
from itertools import zip_longest

# data = pd.read_excel(io = '/content/86 HOTEL RGWLOANER LIST FOR CHI LE.xlsx',sheet_name=3)

# %%
data.head()
# Out:
#             WAREHOUSE                          SHIPPING ADDRESS  CUSTOMER ID  \
# 0  Main DC - Next Day           3233 ST. EDWARDS DR RICHMOND BC       284320
# 1  Main DC - Next Day                      4716 34 ST VERNON BC       284320
# 2  Main DC - Next Day              20 NELSON DR SPRUCE GROVE AB       284320
# 3  Main DC - Next Day  105 BOUL SAINT-JOSEPH O DRUMMONDVILLE QC       284320
# 4  Main DC - Next Day       3451 SOUTH SERVICE RD W OAKVILLE ON       284320
#
#   CLAIM NUMBER FIRST NAME                LAST NAME ORDER CREATE DATE  \
# 0     0017D6F5     JULIAN                 ROZENTAL        2022-09-06
# 1     001749B1     TRENIA                 CHISHOLM        2022-08-05
# 2     0018322C     KALENA                    FEIST        2022-09-27
# 3     0017BF70       COMP  FERME DU CAMPANILE SENC        2022-08-31
# 4     00182E05      CHRIS                NICHOLSON        2022-09-26
#
#      SERIAL NUMBER  PHONE NUMBER PURCHASE DATE ACTIVATION DATE CREATED_DATE_
# ...

# %%
address_data = data['SHIPPING ADDRESS']

# %%
import pandas as pd
import numpy as np
from requests import get
from bs4 import BeautifulSoup
import csv
import re
from itertools import zip_longest

data = pd.read_excel(io = '/content/Shipping Address Data - Jan 14 2023 to Feb 13 2023.xlsx',sheet_name=0) # Enter the Sheet name and sheet number here.

address_data = data['SHIPPING_ADDRESS']     # Enter the name of column for address here
all_links=[]
class Gsearch_python:
   def __init__(self,name_search):
      self.name = name_search
   def Gsearch(self):
      count = 0
      try :
         from googlesearch import search
      except ImportError:
         print("No Module named 'google' Found")
      for i in search(query=self.name,tld='co.in',lang='en',num=10,stop=2,pause=2):
         count += 1
         print (count)
         #print(i)
         #all_links.append(self.name,i)
      patterns = ['hotel', 'motel','airport','reservation']
      for pattern in patterns:
      # print('Looking for "%s" in "%s" ->' % (pattern, i), end=' ')
        if re.search(pattern, i):
          print('Suspected address found!!!!!',i,self.name,"\n")
        else:
          pass
            # print('no match\n')
if __name__=='__main__':
   for i in address_data:
    # print(i)
    gs = Gsearch_python(i)
    gs.Gsearch()
# Out:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2

# %%
import pandas as pd
import numpy as np
from requests import get
from bs4 import BeautifulSoup
import csv
import re
from itertools import zip_longest

data = pd.read_excel(io = '/content/Book1.xlsx',sheet_name=1) # Enter the Sheet name and sheet number here.

address_data = data['SHIPPING_ADDRESS']     # Enter the name of column for address here
all_links=[]
class Gsearch_python:
   def __init__(self,name_search):
      self.name = name_search
   def Gsearch(self):
      count = 0
      try :
         from googlesearch import search
      except ImportError:
         print("No Module named 'google' Found")
      for i in search(query=self.name,tld='co.in',lang='en',num=10,stop=2,pause=2):
         count += 1
         #print (count)
         #print(i)
         #all_links.append(self.name,i)
      patterns = ['hotel', 'motel','airport','reservation','warehouse','distribution center','distribution'] # adding parameters
      for pattern in patterns:
        # print('Looking for "%s" in "%s" ->' % (pattern, i), end=' ')
        if re.search(pattern, i):
            print('Suspected address found!!!!!',i,self.name,"\n")
      else:
        pass
        # print('no match\n')
if __name__=='__main__':
   for i in address_data:
    # print(i)
    gs = Gsearch_python(i)
    gs.Gsearch()
